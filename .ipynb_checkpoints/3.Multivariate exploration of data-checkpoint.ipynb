# %% [markdown]
# # Non-Positional Encodings for Third Variables
# > - Shape for ```quali```tative data, especially good for nominal.
# - Size for ```quanti```tative data, mapping between variable value and size shouldn't be distorted.
# - Color for ```quali```tative and ```quanti```tative data.

# %%
# prerequisite package imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

fuel_df = pd.read_csv('./fuel-econ.csv')
poke_df = pd.read_csv('./pokemon.csv')

# %%
fuel_df.head(3)
# Out:
#       id        make model  year           VClass              drive  \
# 0  32204      Nissan  GT-R  2013  Subcompact Cars    All-Wheel Drive
# 1  32205  Volkswagen    CC  2013     Compact Cars  Front-Wheel Drive
# 2  32206  Volkswagen    CC  2013     Compact Cars  Front-Wheel Drive
#
#                trans          fuelType  cylinders  displ  pv2  pv4     city  \
# 0    Automatic (AM6)  Premium Gasoline          6    3.8   79    0  16.4596
# 1  Automatic (AM-S6)  Premium Gasoline          4    2.0   94    0  21.8706
# 2     Automatic (S6)  Premium Gasoline          6    3.6   94    0  17.4935
#
#      UCity  highway  UHighway     comb  co2  feScore  ghgScore
# 0  20.2988  22.5568   30.1798  18.7389  471        4         4
# 1  26.9770  31.0367   42.4936  25.2227  349        6         6
# 2  21.2000  26.5716   35.1000  20.6716  429        5         5

# %%
poke_df.head(3)
# Out:
#    id    species  generation_id  height  weight  base_experience type_1  \
# 0   1  bulbasaur              1     0.7     6.9               64  grass
# 1   2    ivysaur              1     1.0    13.0              142  grass
# 2   3   venusaur              1     2.0   100.0              236  grass
#
#    type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  poison  45      49       49     45              65               65
# 1  poison  60      62       63     60              80               80
# 2  poison  80      82       83     80             100              100

# %% [markdown]
# ### Shape - Engine size vs. Fuel eff. vs. Transmission type
# > two numeric variables and one categorical variable
#
# #### How to code
# ```python
# cat_markers = [['A', 'o'],
#                ['B', 's']]
#
# for cat, marker in cat_markers:
#     df_cat = df[df['cat_var1'] == cat]
#     # plt.scatter or sns.regplot
#     plt.scatter(data = df_cat, x = 'num_var1', y = 'num_var2', marker = marker)
# plt.legend(['A','B'])
# ```

# %%
# Add a column for only two types of transmisson
fuel_df['trans_type'] = fuel_df.trans.apply(lambda x: x.split()[0])
fuel_df['trans_type'].unique()
# Out:
# array(['Automatic', 'Manual'], dtype=object)

# %%
# sample fewer data to prevent overlapping
np.random.seed(42)
sample = np.random.choice(fuel_df.shape[0], 200, replace=False)
fuel_df_subset = fuel_df.loc[sample]

# %%
ttype_marker = [['Automatic', 'o'],
              ['Manual', '^']]

for ttype, marker in ttype_marker:
    plot_data = fuel_df_subset[fuel_df_subset.trans_type == ttype]
    sns.regplot(data=plot_data, x='displ', y='comb', 
                x_jitter=0.3, 
                fit_reg=False,
                marker=marker)
plt.xlabel('Displacement (l)')
plt.ylabel('Combined Fuel Eff. (mpg)')
plt.legend(['Automatic', 'Manual']);

# %% [markdown]
# ### Size - Engine size vs. Fuel eff. vs. CO2 emission
# > three numeric variables
# #### How to code
# ```python
# plt.scatter(data = df, x = 'num_var1', y = 'num_var2', s = 'num_var3')
#
# # dummy series for adding legend
# sizes = [20, 35, 50]
# base_color = sb.color_palette()[0]
# legend_obj = []
# for s in sizes:
#     legend_obj.append(plt.scatter([], [], s = s, color = base_color))
# plt.legend(legend_obj, sizes)
# ```

# %%
sns.regplot(data=fuel_df_subset, x='displ', y='comb',
            x_jitter=0.3, 
            fit_reg=False,
            scatter_kws={'s': fuel_df_subset['co2']/2}); # /2 for smaller marker size
plt.xlabel('Displacement (l)')
plt.ylabel('Combined Fuel Eff. (mpg)')

# dummy scatter plot sequences for legend
sizes = [200, 350, 500]
base_color = sns.color_palette()[0]
legend_obj = []
for s in sizes:
    legend_obj.append(plt.scatter([],[], s=s/2, color=base_color))
plt.legend(legend_obj, sizes, title='CO2 (g/mi)');

# %% [markdown]
# ### Color
# - Qualitative Palette: Good for nominal data.
# <img src='https://seaborn.pydata.org/_images/color_palettes_6_0.png'>
# - Sequential Palette: Good for ordinal and numeric data.
# <img src='https://seaborn.pydata.org/_images/color_palettes_25_0.png'>
# - Diverging Palette: Good for ordinal and numeric data with a meaningful center point.
# <img src='https://seaborn.pydata.org/_images/color_palettes_55_0.png'>
#
# See [Choosing color palettes](https://seaborn.pydata.org/tutorial/color_palettes.html) for more.
#
# **Be mindful for color blindness**

# %% [markdown]
# ### Engine size vs. Fuel eff. vs. Transmission type
# > Using Qualitative Palette
#
# #### How to code
# ```python
# g = sb.FacetGrid(data = df, hue = 'cat_var1', size = 5)
# g.map(plt.scatter, 'num_var1', 'num_var2')
# g.add_legend()
# ```

# %%
g = sns.FacetGrid(data=fuel_df_subset, hue='trans_type',
                  hue_order=['Automatic', 'Manual'], # Choose which data on top
                  height=4, aspect=1.5) # set figure size
g = g.map(sns.regplot, 'displ', 'comb', fit_reg=False)
g.add_legend()

plt.xlabel('Displacement (l)')
plt.ylabel('Combined Fuel Eff. (mpg)');

# %% [markdown]
# ### Engine size vs. Fuel eff. vs. Car size
# > Using Sequential Palette

# %%
# convert VClass to order categorical type
sedan_cars = ['Minicompact Cars', 'Subcompact Cars', 'Compact Cars', 'Midsize Cars', 'Large Cars']
classes = pd.api.types.CategoricalDtype(ordered=True, categories=sedan_cars)
fuel_df_subset['VClass'] = fuel_df_subset['VClass'].astype(classes)

# %%
g = sns.FacetGrid(data=fuel_df_subset, hue='VClass',
                  palette = 'viridis_r', # Sequential Palette
                  height=4, aspect=1.5) # set figure size
g = g.map(sns.regplot, 'displ', 'comb', fit_reg=False)
g.add_legend()

plt.xlabel('Displacement (l)')
plt.ylabel('Combined Fuel Eff. (mpg)');

# %% [markdown]
# ### Size - Engine size vs. Fuel eff. vs. CO2 emission
# > Using Sequential Palette
#
# #### How to code
# ```python
# plt.scatter(data = df, x = 'num_var1', y = 'num_var2', c = 'num_var3')
# plt.colorbar()
# ```

# %%
# Using FacetGrid will create a messy, long legend
plt.scatter(data=fuel_df_subset, x='displ', y='comb', c='co2', cmap='hot_r')
plt.colorbar(label='CO2 (g/mu)');

# %% [markdown]
# ### Further Reading
# - Eager Eyes: [How The Rainbow Color Map Misleads](https://eagereyes.org/basics/rainbow-color-map) - seaborn will refuse to accept the 'jet' palette string, which corresponds with a rainbow-colored palette that covers the entire range of hues. This, and the next link, will tell you why it's been forbidden.
# - Agile Scientific: [No more rainbows!](https://agilescientific.com/blog/2017/12/14/no-more-rainbows)
# - Datawrapper: [How to Choose a Color Palette for Choropleth Maps](https://blog.datawrapper.de/how-to-choose-a-color-palette-for-choropleth-maps/) - Though this article discusses color in the context of maps and for a specific software tool, it's a useful reference if you want to create a non-linear normalization function.-

# %% [markdown]
# # Faceting in Two Directions
# FacetGrid also allows for faceting a variable not just by columns, but also by rows. We can set one categorical variable on each of the two facet axes for one additional method of depicting multivariate trends.
# #### How to code
# ```python
# g = sb.FacetGrid(data = df, col = 'cat_var2', row = 'cat_var1', size = 2.5,
#                 margin_titles = True)
# g.map(plt.scatter, 'num_var1', 'num_var2')
# ```
# > Setting ```margin_titles = True``` means that instead of each facet being labeled with the combination of row and column variable, labels are placed separately on the top and right margins of the facet grid.

# %%
g = sns.FacetGrid(data=fuel_df, col='VClass',
                  row='trans_type', 
                  margin_titles=True)
g.map(plt.scatter, 'displ', 'comb');

# %% [markdown]
# # Other Adaptations of Bivariate Plots
# ## Alternative approach for two categorical variables and one numeric variable
# ### pointplot
# #### How to code
# ```python
# ax = sb.pointplot(data = df, x = 'cat_var1', y = 'num_var2', hue = 'cat_var2',
#                   dodge = 0.3, linestyles = "")
# ```

# %%
sns.pointplot(data=fuel_df, x='VClass', y='comb', 
              hue='trans_type', # add the third variable
              dodge=True, # prevent overlapping
              ci='sd', # set uncertainty to standard deviation
              linestyles='')
plt.xticks(rotation=15)
plt.ylabel('Combined Fuel Eff. (mpg)');

# %% [markdown]
# ### Barplot
# #### How to code
# ```python
# ax = sb.barplot(data = df, x = 'cat_var1', y = 'num_var2', hue = 'cat_var2')
# ax.legend(loc = 8, ncol = 3, framealpha = 1, title = 'cat_var2')
# ```

# %%
sns.barplot(data=fuel_df, x='VClass', y='comb', hue='trans_type', ci='sd')
plt.xticks(rotation=15)
plt.ylabel('Combined Fuel Eff. (mpg)');

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(data=fuel_df, x='VClass', y='comb', hue='trans_type')
plt.xticks(rotation=15)
plt.ylabel('Combined Fuel Eff. (mpg)');

# %% [markdown]
# ### Depict the mean of a third variable in a 2-d histogram - hist2d
# #### How to code
# ```python
# xbin_edges = np.arange(0.25, df['num_var1'].max()+0.5, 0.5)
# ybin_edges = np.arange(7,    df['num_var2'].max()+0.5, 0.5)
#
# # count number of points in each bin
# xbin_idxs = pd.cut(df['num_var1'], xbin_edges, right = False,
#                     include_lowest = True, labels = False).astype(int)
# ybin_idxs = pd.cut(df['num_var2'], ybin_edges, right = False,
#                     include_lowest = True, labels = False).astype(int)
#
# pts_per_bin = df.groupby([xbin_idxs, ybin_idxs]).size()
# pts_per_bin = pts_per_bin.reset_index()
# pts_per_bin = pts_per_bin.pivot(index = 'num_var1', columns = 'num_var2').values
#
# z_wts = df['num_var3'] / pts_per_bin[xbin_idxs, ybin_idxs]
#
# # plot the data using the calculated weights
# plt.hist2d(data = df, x = 'num_var1', y = 'num_var2', weights = z_wts,
#            bins = [xbin_edges, ybin_edges], cmap = 'viridis_r', cmin = 0.5);
# plt.xlabel('num_var1')
# plt.ylabel('num_var2');
# plt.colorbar(label = 'mean(num_var3)');
# ```

# %%
bins_x = np.arange(fuel_df.displ.min(), fuel_df.displ.max()+0.3, 0.3)
bins_y = np.arange(12, 58+3, 3)

# Set co2 weight to co2 emission / # of cars in its bin
displ_bins = pd.cut(fuel_df['displ'], bins_x, right=False, include_lowest=True, labels=False).astype(int)
comb_bins = pd.cut(fuel_df['comb'], bins_y, right=False, include_lowest=True, labels=False).astype(int)
n_points = fuel_df.groupby([displ_bins, comb_bins]).size()
n_points = n_points.reset_index().pivot(index='displ', columns='comb').values
co2weight = fuel_df['co2'] / n_points[displ_bins, comb_bins]

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.hist2d(data=fuel_df, x='displ', y='comb', cmin=0.5, cmap='hot_r', bins=[bins_x, bins_y],
           weights=co2weight)
plt.xlabel('Displacement (l)')
plt.ylabel('Combined Fuel Eff. (mpg)')
plt.colorbar();

plt.subplot(1, 2, 2)
# Using FacetGrid will create a messy, long legend
plt.scatter(data=fuel_df, x='displ', y='comb', c='co2', cmap='hot_r')
plt.colorbar(label='CO2 (g/mu)');

# %% [markdown]
# ### Depict the mean of a third variable in a line plot - errorbar
#
# ```python
# def mean_poly(x, y, bins = 10, **kwargs):
#     """ Custom adapted line plot code. """
#     # set bin edges if none or int specified
#     if type(bins) == int:
#         bins = np.linspace(x.min(), x.max(), bins+1)
#     bin_centers = (bin_edges[1:] + bin_edges[:-1]) / 2
#
#     # compute counts
#     data_bins = pd.cut(x, bins, right = False,
#                        include_lowest = True)
#     means = y.groupby(data_bins).mean()
#
#     # create plot
#     plt.errorbar(x = bin_centers, y = means, **kwargs)
#
# bin_edges = np.arange(0.25, df['num_var1'].max()+0.5, 0.5)
# g = sb.FacetGrid(data = df, hue = 'cat_var2', size = 5)
# g.map(mean_poly, "num_var1", "num_var2", bins = bin_edges)
# g.set_ylabels('mean(num_var2)')
# g.add_legend()
# ```

# %%
def mean_poly(x, y, bins = 10, **kwargs):
    """ Custom adapted line plot code. """
    # set bin edges if none or int specified
    if type(bins) == int:
        bins = np.linspace(x.min(), x.max(), bins+1)
    bin_centers = (bin_edges[1:] + bin_edges[:-1]) / 2

    # compute counts
    data_bins = pd.cut(x, bins, right = False,
                       include_lowest = True)
    means = y.groupby(data_bins).mean().tolist()

    # create plot
    plt.errorbar(x = bin_centers, y = means, **kwargs)
    
bin_edges = bins_x
g = sns.FacetGrid(data = fuel_df, hue = 'VClass', height = 5)
g.map(mean_poly, "displ", "comb", bins = bin_edges)
g.set_ylabels('mean Combined Fuel Eff. (mpg)')
g.add_legend();
